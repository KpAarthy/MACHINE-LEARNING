# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
ds=pd.read_csv('diabetes.csv')
ds
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
ds1=ds.rename(columns={"BloodPressure":"BP","SkinThickness":"ST","DiabetesPedigreeFunction":"DPF",})
ds1
# Out:
#      Pregnancies  Glucose  BP  ST  Insulin   BMI    DPF  Age  Outcome
# 0              6      148  72  35        0  33.6  0.627   50        1
# 1              1       85  66  29        0  26.6  0.351   31        0
# 2              8      183  64   0        0  23.3  0.672   32        1
# 3              1       89  66  23       94  28.1  0.167   21        0
# 4              0      137  40  35      168  43.1  2.288   33        1
# ..           ...      ...  ..  ..      ...   ...    ...  ...      ...
# 763           10      101  76  48      180  32.9  0.171   63        0
# 764            2      122  70  27        0  36.8  0.340   27        0
# 765            5      121  72  23      112  26.2  0.245   30        0
# 766            1      126  60   0        0  30.1  0.349   47        1
# 767            1       93  70  31        0  30.4  0.315   23        0
#
# [768 rows x 9 columns]

# %%
ds1.shape
# Out:
# (768, 9)

# %%
ds1.head(10)

# %%
sns.scatterplot(x=ds1['Pregnancies'], y=ds1['Glucose'], hue=ds1['Outcome'], style=ds1['BMI'])
plt.show()

# %%
sns.pairplot(ds1, hue='Outcome',height=2)
plt.show()

# %%
plt.hist(ds1['Pregnancies'], bins=20, rwidth=0.5, align='left', color='blue')
plt.show()

# %%
sns.boxplot(ds1['Pregnancies'],orient='h', color='blue', order=7, linewidth=5)
plt.show()
# Out:
# C:\Users\SKS\Desktop\IMAGE_CLASSIFICATION\test01\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
